# %%
from scipy import stats

# Create a normal distribution
mean, std = 50, 10
dist = stats.norm(mean, std)

# Probability that value is less than 60
prob = dist.cdf(60)
print("P(X < 60):", prob)

# Generate random samples
samples = dist.rvs(size=5)
print("Random samples:", samples)
# Out:
# P(X < 60): 0.8413447460685429
# Random samples: [35.57001754 45.06569191 55.40736762 61.22148894 46.66670109]

# %%
from scipy import stats

group_A = [20, 22, 23, 21, 24]
group_B = [30, 32, 31, 29, 33]

t_stat, p_value = stats.ttest_ind(group_A, group_B)
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -9.0
# p-value: 1.85311842964301e-05

# %%
from scipy.optimize import minimize

# Function to minimize
def f(x):
    return x**2 + 4*x + 4

result = minimize(f, x0=0)
print("Minimum at x =", result.x)
print("Minimum value =", result.fun)
# Out:
# Minimum at x = [-2.00000002]
# Minimum value = 0.0

# %%
from scipy.linalg import inv
import numpy as np

A = np.array([[1, 2], [3, 4]])

A_inv = inv(A)
print(A_inv)
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
import numpy as np
from scipy.optimize import curve_fit

# Model
def model(x, a, b):
    return a*x + b

x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

params, _ = curve_fit(model, x, y)
print("a =", params[0], "b =", params[1])
# Out:
# a = 2.0 b = 4.440892098500626e-16

# %%
from scipy import stats
dist = stats.norm(50, 10)
dist.cdf(60)
# Out:
# np.float64(0.8413447460685429)
